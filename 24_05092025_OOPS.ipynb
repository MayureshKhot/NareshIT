# %%
24

# %% [markdown]
# # Class
# - Class is a blue print of objects.
#
# 1. Inbuilt class
# 3. User defined class

# %%
class laptop():
    def confit(): #withing the class it is a method, outside of class it's called function
        print('i5', '8gb')
