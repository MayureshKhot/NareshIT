# %% [markdown]
# # Statistics
# 1. Population & sample
#    1. Population
#    2. Sample
# 3. Descriptive Stats
#    1. Measure of central tendency
#    2. measure of assymetry
#    3. measure of variablity
#    4. measure of relationship
# 5. Inferential stats
#    1. Probability
#    2. Distribution
#    3. Confidence Interval
#    4. Z-Test
#    5. T-test
# 7. Advanced stats
#    1. Hypothesis testing
#    2. Accept Null hypothesis
#    3. Reject Null hypothesis
# 9. Stats linear regression
#    1. y=mx+c
#    2. loss function | cost function
#    3. adjusted r2
#    4. r2
#    5. anova frame
#    6. ssr, sst, se
#
#
# ## ML
# - ML devided into 3 parts:
# - 1. Regression
#      1. Supervised learning
#      2. label learning
#      3. predictive learning
#   2. Classification
#      1. Supervise learning = label data = predictive data
#   3. Clustering
#      1. Unsupervised learning = unable = unpredictive data
#
# $Why we need statistics for machine learning?$
# - To measure the accuracy of the model (Check again)
